# %%
pip install matplotlib
# Out:
# ...
#   Using cached matplotlib-3.10.1-cp310-cp310-macosx_10_12_x86_64.whl.metadata (11 kB)
# ...
#   Using cached contourpy-1.3.2-cp310-cp310-macosx_10_9_x86_64.whl.metadata (5.5 kB)
# ...
#   Using cached cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# ...
#   Using cached fonttools-4.57.0-cp310-cp310-macosx_10_9_x86_64.whl.metadata (102 kB)
# ...
#   Using cached kiwisolver-1.4.8-cp310-cp310-macosx_10_9_x86_64.whl.metadata (6.2 kB)
# ...
#   Using cached pillow-11.2.1-cp310-cp310-macosx_10_10_x86_64.whl.metadata (8.9 kB)
# ...
#   Using cached pyparsing-3.2.3-py3-none-any.whl.metadata (5.0 kB)
# ...
# Using cached matplotlib-3.10.1-cp310-cp310-macosx_10_12_x86_64.whl (8.2 MB)
# Using cached contourpy-1.3.2-cp310-cp310-macosx_10_9_x86_64.whl (268 kB)
# Using cached cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Using cached fonttools-4.57.0-cp310-cp310-macosx_10_9_x86_64.whl (2.3 MB)
# Using cached kiwisolver-1.4.8-cp310-cp310-macosx_10_9_x86_64.whl (66 kB)
# Using cached pillow-11.2.1-cp310-cp310-macosx_10_10_x86_64.whl (3.2 MB)
# ...

# %%
pip install seaborn
# Out:
# ...
#   Using cached seaborn-0.13.2-py3-none-any.whl.metadata (5.4 kB)
# ...
# Using cached seaborn-0.13.2-py3-none-any.whl (294 kB)
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("/Users/mac/HB1_VISA_PREDICTION/Data/raw/olfc-data.csv")
df.head()
# Out:
#   case_id continent education_of_employee has_job_experience  \
# 0  EZYV01      Asia           High School                  N
# 1  EZYV02      Asia              Master's                  Y
# 2  EZYV03      Asia            Bachelor's                  N
# 3  EZYV04      Asia            Bachelor's                  N
# 4  EZYV05    Africa              Master's                  Y
#
#   requires_job_training  no_of_employees  yr_of_estab region_of_employment  \
# 0                     N            14513         2007                 West
# 1                     N             2412         2002            Northeast
# 2                     Y            44444         2008                 West
# 3                     N               98         1897                 West
# 4                     N             1082         2005                South
#
#    prevailing_wage unit_of_wage full_time_position case_status
# 0         592.2029         Hour                  Y      Denied
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25480 entries, 0 to 25479
# Data columns (total 12 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   case_id                25480 non-null  object
#  1   continent              25480 non-null  object
#  2   education_of_employee  25480 non-null  object
#  3   has_job_experience     25480 non-null  object
#  4   requires_job_training  25480 non-null  object
#  5   no_of_employees        25480 non-null  int64
#  6   yr_of_estab            25480 non-null  int64
#  7   region_of_employment   25480 non-null  object
#  8   prevailing_wage        25480 non-null  float64
#  9   unit_of_wage           25480 non-null  object
#  10  full_time_position     25480 non-null  object
#  11  case_status            25480 non-null  object
# dtypes: float64(1), int64(2), object(9)
# memory usage: 2.3+ MB

# %%
df.describe()
# Out:
#        no_of_employees   yr_of_estab  prevailing_wage
# count     25480.000000  25480.000000     25480.000000
# mean       5667.043210   1979.409929     74455.814592
# std       22877.928848     42.366929     52815.942327
# min         -26.000000   1800.000000         2.136700
# 25%        1022.000000   1976.000000     34015.480000
# 50%        2109.000000   1997.000000     70308.210000
# 75%        3504.000000   2005.000000    107735.512500
# max      602069.000000   2016.000000    319210.270000

# %%
df.isnull().sum()
# Out:
# case_id                  0
# continent                0
# education_of_employee    0
# has_job_experience       0
# requires_job_training    0
# no_of_employees          0
# yr_of_estab              0
# region_of_employment     0
# prevailing_wage          0
# unit_of_wage             0
# full_time_position       0
# case_status              0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# EDA

# %% [markdown]
# Monovariate Analysis

# %%
plt.figure(figsize=(6,4))
sns.countplot(data=df, x='case_status', palette='pastel')
plt.title('Distribution of Case Status')

plt.figure(figsize=(8,6))
sns.countplot(data=df, x='continent', palette='Set2')
plt.title('Distribution of Applicants by Continent')

plt.figure(figsize=(8,6))
sns.countplot(data=df, x='education_of_employee', palette='Set3')
plt.title('Education Level of Employees')

plt.figure(figsize=(8,6))
sns.countplot(data=df, x='has_job_experience', palette='Set2')
plt.title('Has Job Experince')

plt.figure(figsize=(8,6))
sns.countplot(data=df, x='requires_job_training', palette='Set1')
plt.title('Requires Job Training')

#  Full-time Position
plt.figure(figsize=(8,6))
sns.countplot(data=df, x='full_time_position', palette='Set2')
plt.title('Is Full-Time Position')

#  Unit of Wage
plt.figure(figsize=(8,6))
sns.countplot(data=df, x='unit_of_wage', palette='cool')
plt.title('Unit of Wage')

# Prevailing Wage
plt.figure(figsize=(8,6))
sns.histplot(df['prevailing_wage'], kde=True, color='purple', bins=50, log_scale=True)
plt.title('Distribution of Prevailing Wages (Log Scale)')


plt.tight_layout()
plt.show()

# %% [markdown]
# Bivariate Analysis

# %%
#Case Status by Education
plt.figure(figsize=(8, 6))
sns.countplot(data=df, x='education_of_employee', hue='case_status', palette='Set2')
plt.title('Case Status by Education Level')
plt.xticks(rotation=45)

#Case Status by Continent
plt.figure(figsize=(8, 6))
sns.countplot(data=df, x='continent', hue='case_status', palette='Set3')
plt.title('Case Status by Continent')
plt.xticks(rotation=45)

#Job Experience by Case Status
plt.figure(figsize=(8, 6))
sns.countplot(data=df, x='has_job_experience', hue='case_status', palette='Set1')
plt.title('Case Status by Job Experience')

#Training Requirement by Case Status
plt.figure(figsize=(8, 6))
sns.countplot(data=df, x='requires_job_training', hue='case_status', palette='coolwarm')
plt.title('Case Status by Job Training Requirement')

#Full-Time Position by Case Status
plt.figure(figsize=(8, 6))
sns.countplot(data=df, x='full_time_position', hue='case_status', palette='Set2')
plt.title('Case Status by Full-time Position')

#Unit of Wage by Case Status
plt.figure(figsize=(8, 6))
sns.countplot(data=df, x='unit_of_wage', hue='case_status', palette='mako')
plt.title('Case Status by Wage Unit')

#Full-Time vs Experience
plt.figure(figsize=(8,6))
sns.countplot(data=df, x='full_time_position', hue='has_job_experience', palette='cool', dodge=True)
plt.title('Full-Time & Job Experience Relationship')

#  egion by Case Status
plt.figure(figsize=(8, 6))
sns.countplot(data=df, x='region_of_employment', hue='case_status', palette='husl')
plt.title('Case Status by Region of Employment')
plt.xticks(rotation=45)
# Out:
# ([0, 1, 2, 3, 4],
#  [Text(0, 0, 'West'),
#   Text(1, 0, 'Northeast'),
#   Text(2, 0, 'South'),
#   Text(3, 0, 'Midwest'),
#   Text(4, 0, 'Island')])

# %% [markdown]
# Multivariate Analysis

# %%
#creating unit multiplers and Normalized wage
df['unit_of_wage'].value_counts(normalize=True) * 100
# Out:
# unit_of_wage
# Year     90.117739
# Hour      8.465463
# Week      1.067504
# Month     0.349294
# Name: proportion, dtype: float64

# %%
# Define conversion multipliers
conversion_factors = {
    'Hour': 2080,       # 40 hours/week × 52 weeks/year
    'Week': 52,
    'Month': 12,
    'Year': 1
}

# Apply conversion to standardize wages to yearly
df['prevailing_wage'] = df.apply(
    lambda row: row['prevailing_wage'] * conversion_factors[row['unit_of_wage']], axis=1
)

# Standardize unit
df['unit_of_wage'] = 'Year'

# %%
df
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %%
df['prevailing_wage'] = df['prevailing_wage'].round(0).astype(int)

# %%
df
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %%
plt.figure(figsize=(8,6))
sns.countplot(data=df[df['requires_job_training'] == 'Y'], x='education_of_employee', hue='case_status', palette='Set2')
plt.title('Education vs Training Required (Certified vs Denied)')
plt.xticks(rotation=45)
# Out:
# ([0, 1, 2, 3],
#  [Text(0, 0, "Bachelor's"),
#   Text(1, 0, "Master's"),
#   Text(2, 0, 'High School'),
#   Text(3, 0, 'Doctorate')])

# %%
#Correlation Heatmap
plt.figure(figsize=(8,6))
num_df = df[['no_of_employees', 'yr_of_estab', 'normalized_wage']]
corr = num_df.corr()
sns.heatmap(corr, annot=True, cmap='coolwarm', fmt=".2f")
plt.title('Correlation Between Numeric Features')
# Out:
# Text(0.5, 1.0, 'Correlation Between Numeric Features')

# %%
df.to_csv('Cleaned_data.csv', index = False)

# %% [markdown]
# Feature Engineering
# for this new column will be created such as :
# company age- as this may affects the ability or credibility to get application certified
# large company- how large is the company , company staff base
#
#
# Existing columns will also be dropped
# Unit of wage- not needed as after normalized_wage is created
# yr_of_estab= company age created
# prevailing wage-  not needed as after normalized_wage is created

# %%
# Create a binary flag for large companies
df['large_employer'] = df['no_of_employees'] > 100

#Create company age
df['company_age'] = 2025 - df['yr_of_estab']

binary_cols = ['full_time_position', 'has_job_experience', 'requires_job_training']
for col in binary_cols:
    df[col] = df[col].map({'Y': 1, 'N': 0})

# %%
df.head(2)
# Out:
#   case_id continent education_of_employee  has_job_experience  \
# 0  EZYV01      Asia           High School                   0
# 1  EZYV02      Asia              Master's                   1
#
#    requires_job_training  no_of_employees  yr_of_estab region_of_employment  \
# 0                      0            14513         2007                 West
# 1                      0             2412         2002            Northeast
#
#    prevailing_wage unit_of_wage  full_time_position case_status  \
# 0         592.2029         Hour                   1      Denied
# 1       83425.6500         Year                   1   Certified
#
#    normalized_wage  large_employer  company_age
# 0      1231782.032            True           18
# 1        83425.650            True           23

# %%
categorical_columns = df.select_dtypes(include="object").columns.to_list()

encoder = LabelEncoder()


for column_name in categorical_columns:
   df[column_name] = encoder.fit_transform(df[column_name])

# %%
df.head()
# Out:
#    case_id  continent  education_of_employee  has_job_experience  \
# 0        0          1                      2                   0
# 1        1          1                      3                   1
# 2        2          1                      0                   0
# 3        3          1                      0                   0
# 4        4          0                      3                   1
#
#    requires_job_training  no_of_employees  yr_of_estab  region_of_employment  \
# 0                      0            14513         2007                     4
# 1                      0             2412         2002                     2
# 2                      1            44444         2008                     4
# 3                      0               98         1897                     4
# 4                      0             1082         2005                     3
#
#    prevailing_wage  unit_of_wage  full_time_position  case_status  \
# ...

# %%
label = df["case_status"]
features = df.drop("case_status",axis = 1)

# %%
columns_to_drop = ['case_id', 'yr_of_estab', 'unit_of_wage', 'prevailing_wage']
# Drop the columns
features1 = features.drop(columns=columns_to_drop)

features1.head()
# Out:
#    continent  education_of_employee  has_job_experience  \
# 0          1                      2                   0
# 1          1                      3                   1
# 2          1                      0                   0
# 3          1                      0                   0
# 4          0                      3                   1
#
#    requires_job_training  no_of_employees  region_of_employment  \
# 0                      0            14513                     4
# 1                      0             2412                     2
# 2                      1            44444                     4
# 3                      0               98                     4
# 4                      0             1082                     3
#
#    full_time_position  normalized_wage  large_employer  company_age
# 0                   1      1231782.032            True           18
# 1                   1        83425.650            True           23
# ...

# %%
#Normalisation to deal with outliers
scaler = MinMaxScaler()
features1["Scaled_no_of_employees"] = scaler.fit_transform(features1["no_of_employees"].values.reshape(-1,1))
features1["Scaled_normalized_wage"] = scaler.fit_transform(features1["normalized_wage"].values.reshape(-1,1))

features1.drop(["no_of_employees","normalized_wage"],axis=1, inplace=True)

# %%
features1.head()
# Out:
#    continent  education_of_employee  has_job_experience  \
# 0          1                      2                   0
# 1          1                      3                   1
# 2          1                      0                   0
# 3          1                      0                   0
# 4          0                      3                   1
#
#    requires_job_training  region_of_employment  full_time_position  \
# 0                      0                     4                   1
# 1                      0                     2                   1
# 2                      1                     4                   1
# 3                      0                     4                   1
# 4                      0                     3                   1
#
#    large_employer  company_age  Scaled_no_of_employees  Scaled_normalized_wage
# 0            True           18                0.024147                0.084541
# ...

# %%
features1["large_employer"] = features1["large_employer"].astype(int)

# %%
features1.head()
# Out:
#    continent  education_of_employee  has_job_experience  \
# 0          1                      2                   0
# 1          1                      3                   1
# 2          1                      0                   0
# 3          1                      0                   0
# 4          0                      3                   1
#
#    requires_job_training  region_of_employment  full_time_position  \
# 0                      0                     4                   1
# 1                      0                     2                   1
# 2                      1                     4                   1
# 3                      0                     4                   1
# 4                      0                     3                   1
#
#    large_employer  company_age  Scaled_no_of_employees  Scaled_normalized_wage
# 0               1           18                0.024147                0.084541
# ...

# %% [markdown]
# Modelling

# %%
X_train, X_test, y_train, y_test = train_test_split(
 features1,label,test_size=0.2, random_state=42, stratify=label
)

 #Apply SMOTE on training data only
smote = SMOTE(random_state=42)
X_train_smote, y_train_smote = smote.fit_resample(X_train, y_train)


#Print class distribution before and after
print("Before SMOTE:", Counter(y_train))
print("After SMOTE:", Counter(y_train_smote))
# Out:
# Before SMOTE: Counter({0: 13614, 1: 6770})
# After SMOTE: Counter({1: 13614, 0: 13614})

# %%
# Initialize and train the models
classifiers = [[LogisticRegression(random_state=42), 'Logistic Regression'],
               [SGDClassifier(random_state=42), 'SGD Classifiers'],
               [DecisionTreeClassifier(random_state=42), 'Decision Tree'],
               [RandomForestClassifier(random_state=42), 'Random Forest'],
               [XGBClassifier(random_state=42),'XGBClassifier']
              ]

for classifier in classifiers:
    model_name = classifier[1]
    model = classifier[0]
    print(f"<-- {model_name} -->")
    model.fit(X_train_smote, y_train_smote)
    predictions = model.predict(X_test)
    report = classification_report(y_test, predictions)
    matrix = confusion_matrix(y_test, predictions)
    print("Classification Report:\n", report)
    sns.heatmap(matrix, annot=True, fmt='g')
    plt.show()
# Out:
# <-- Logistic Regression -->
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.75      0.68      0.71      3404
#            1       0.46      0.55      0.50      1692
#
#     accuracy                           0.63      5096
#    macro avg       0.60      0.61      0.61      5096
# weighted avg       0.65      0.63      0.64      5096
# <-- SGD Classifiers -->
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.78      0.39      0.52      3404
#            1       0.39      0.78      0.52      1692
#
#     accuracy                           0.52      5096
#    macro avg       0.58      0.59      0.52      5096
# weighted avg       0.65      0.52      0.52      5096
# <-- Decision Tree -->
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.75      0.67      0.71      3404
# ...

# %%
#Train LSTM
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)


#Train LSTM
# Reshape for LSTM: (samples, time_steps, features)
X_train_lstm = X_train_scaled.reshape((X_train_scaled.shape[0], 1, X_train_scaled.shape[1]))
X_test_lstm = X_test_scaled.reshape((X_test_scaled.shape[0], 1, X_test_scaled.shape[1]))

# Build the LSTM model
lstm_model = Sequential()
lstm_model.add(LSTM(64, input_shape=(1, X_train_lstm.shape[2]), return_sequences=False))
lstm_model.add(Dropout(0.3))
lstm_model.add(Dense(32, activation='relu'))
lstm_model.add(Dense(1, activation='sigmoid'))

lstm_model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# Train LSTM
lstm_model.fit(X_train_lstm, y_train, epochs=20, batch_size=32, validation_split=0.2, verbose=0)

# Predict with LSTM
y_pred_lstm = lstm_model.predict(X_test_lstm)
y_pred_lstm_labels = (y_pred_lstm > 0.5).astype(int).flatten()

# Evaluate LSTM
print("LSTM Report:\n", classification_report(y_test, y_pred_lstm_labels))
# Out:
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# LSTM Report:
#                precision    recall  f1-score   support
#
#            0       0.75      0.88      0.81      3404
#            1       0.63      0.42      0.50      1692
#
#     accuracy                           0.72      5096
#    macro avg       0.69      0.65      0.66      5096
# weighted avg       0.71      0.72      0.71      5096

# %% [markdown]
# Hyper parameter tunning for the best performaning model.
# Best performaning model is XGBClassifier

# %%
#  Define the model
xgb = XGBClassifier(random_state=42, use_label_encoder=False, eval_metric='logloss')

# Define hyperparameter grid
param_dist = {
    'n_estimators': [100, 200, 300, 400, 500],
    'max_depth': [3, 5, 7, 10, 15],
    'learning_rate': [0.01, 0.05, 0.1, 0.2],
    'subsample': [0.6, 0.8, 1.0],
    'colsample_bytree': [0.6, 0.8, 1.0],
    'gamma': [0, 0.1, 0.3, 0.5],
    'min_child_weight': [1, 3, 5]
}

#  Randomized Search
random_search = RandomizedSearchCV(
    xgb,
    param_distributions=param_dist,
    n_iter=50,  
    scoring='f1',  # Since we care about class 1 detection (minority class)
    cv=3,  # 3-Fold Cross Validation
    verbose=2,
    random_state=42,
    t
# Out:
# Fitting 3 folds for each of 50 candidates, totalling 150 fits
# Best Parameters Found: {'subsample': 0.8, 'n_estimators': 200, 'min_child_weight': 3, 'max_depth': 15, 'learning_rate': 0.1, 'gamma': 0, 'colsample_bytree': 1.0}
#               precision    recall  f1-score   support
#
#            0       0.78      0.73      0.75      3404
#            1       0.52      0.60      0.56      1692
#
#     accuracy                           0.68      5096
#    macro avg       0.65      0.66      0.66      5096
# weighted avg       0.70      0.68      0.69      5096

# %%
# Predict probabilities for X_test
y_proba = best_xgb.predict_proba(X_test)[:, 1]  # Get probabilities for class 1

#  Calculate False Positive Rate (FPR), True Positive Rate (TPR)
fpr, tpr, thresholds = roc_curve(y_test, y_proba)

#  Calculate AUC (Area Under Curve)
roc_auc = auc(fpr, tpr)

# Step 11: Plot ROC Curve
plt.figure(figsize=(8,6))
plt.plot(fpr, tpr, color='blue', lw=2, label=f'XGBoost ROC curve (AUC = {roc_auc:.2f})')
plt.plot([0, 1], [0, 1], color='grey', linestyle='--')  # Diagonal line
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curve - Tuned XGBoost Model')
plt.legend(loc="lower right")
plt.grid()
plt.show()
